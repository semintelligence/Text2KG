# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
fil=open('/content/drive/MyDrive/Text2KG paper Material - V2/Raw CD Files/1592674.txt')

# %%
tok_ent = pd.read_table('/content/drive/MyDrive/Text2KG paper Material - V2/ner1592674.txt',delimiter=' - ',engine='python')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-82f1e540abb0> in <module>()
# ----> 1 tok_ent = pd.read_table('/content/drive/MyDrive/KKR Project/Text2KG paper Material/ner1592674.txt',delimiter=' - ',engine='python')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
tok_ent
# Out:
#                                                  Token            Entity
# 0                          Appeal (civil) 5405 of 1995              CASE
# 1                                           PETITIONER  PARTICIPANT_TYPE
# 2        ASSTT. GEN. MANAGER CENTRAL BANK OF INDIA ETC       PARTICIPANT
# 3                                           RESPONDENT  PARTICIPANT_TYPE
# 4    COMMISSIONER MUNICIPAL CORPORATION AHMEDABAD E...       PARTICIPANT
# ..                                                 ...               ...
# 119                                         High Court             COURT
# 120                                        High Courts             COURT
# 121                                         High Court             COURT
# 122                                         High Court             COURT
# 123                         Municipal Corporations Act               LAW
#
# [124 rows x 2 columns]

# %%
tok_ent.shape[0]
# Out:
# 124

# %%
tok_ent['Entity'].value_counts()
# Out:
# LAW                 71
# PARTICIPANT         19
# COURT               12
# PARTICIPANT_TYPE     9
# DOCUMENT             4
# DATE                 2
# BENCH                2
# COURT_DECISION       2
# CASE                 1
# CASE_TYPE            1
# Name: Entity, dtype: int64

# %%
for i in range(tok_ent.shape[0]):
  if tok_ent['Entity'][i] == 'CASE':
    print('CASE hasCaseNo',tok_ent['Token'][i])
  elif tok_ent['Entity'][i] =='PARTICIPANT_TYPE':
    print('CASE hasParticipantType',tok_ent['Token'][i])
  elif tok_ent['Entity'][i] == 'PARTICIPANT':
    if tok_ent['Token'][i]=='BENCH':
      pass
    #  for t in tok_ent[tok_ent['Entity']=='BENCH']:
    #    print('BENCH hasJudge',t)
    else:
      print('PARTICIPANT hasName',tok_ent['Token'][i])
  elif tok_ent['Entity'][i] == 'BENCH':
    print('BENCH hasJudge',tok_ent['Token'][i])
  elif tok_ent['Entity'][i] == 'COURT':
    print('COURT hasName',tok_ent['Token'][i])
  elif tok_ent['Entity'][i] == 'LAW':
    print('CASE hasLaw',tok_ent['Token'][i])
  elif tok_ent['Entity'][i] == 'CASE_TYPE':
    print('CASE hasType',tok_ent['Token'][i])
  elif tok_ent['Entity'][i] == 'COURT_DECISION':
    print('CASE hasDecision',tok_ent['Token'][i])
# Out:
# CASE hasCaseNo Appeal (civil) 5405 of 1995
# CASE hasParticipantType PETITIONER
# PARTICIPANT hasName ASSTT. GEN. MANAGER CENTRAL BANK OF INDIA ETC
# CASE hasParticipantType RESPONDENT
# PARTICIPANT hasName COMMISSIONER MUNICIPAL CORPORATION AHMEDABAD ETC. ETC
# BENCH hasJudge B.P. JEEVAN REDDY
# BENCH hasJudge SUJATA V. MANOHAR
# CASE hasDecision JUDGMENT 1995 (1) Suppl. SCR 63
# PARTICIPANT hasName B.P. JEEVAN REDDY
# CASE hasDecision Leave granted
# PARTICIPANT hasName S/Sri G.L
# PARTICIPANT hasName Sanghi
# PARTICIPANT hasName Rohinton Nariman
# PARTICIPANT hasName V.R. Reddy and Andhyarujina
# CASE hasParticipantType appellants
# PARTICIPANT hasName S/Sri F.S. Nariman
# PARTICIPANT hasName Soli Sorabjee
# PARTICIPANT hasName B.K. Mehta
# CASE hasParticipantType respondents
# COURT hasName Gujarat High Court
# CASE hasLaw Bombay Provincial Municipal Corporation Act, 1949
# CASE hasLaw Bombay Rents, Hotel and Lodging House Rates Control Act, 1944
# ...

# %%
data_text = fil.read()
type(data_text)
# Out:
# str

# %%
data_text
# Out:
# 'CASE NO.: Appeal (civil) 5405 of 1995 PETITIONER: ASSTT. GEN. MANAGER CENTRAL BANK OF INDIA ETC. RESPONDENT: COMMISSIONER MUNICIPAL CORPORATION AHMEDABAD ETC. ETC. DATE OF JUDGMENT: 09/05/1995 BENCH: B.P. JEEVAN REDDY & SUJATA V. MANOHAR JUDGMENT: JUDGMENT 1995 (1) Suppl. SCR 63 The Judgment of the Court was delivered by B.P. JEEVAN REDDY, J. Delay condoned. Leave granted. Heard S/Sri G.L, Sanghi, Rohinton Nariman, V.R. Reddy and Andhyarujina for the appellants and S/Sri F.S. Nariman, Soli Sorabjee, B.K. Mehta for the respondents. These appeals are preferred against the judgment of the Gujarat High Court in a batch of first appeals. Two questions arise for consideration viz., (i) whether a tenant of a building is entitled to file and maintain an appeal against the order assessing the property tax under the provision of the Bombay Provincial Municipal Corporation Act, 1949 as applicable in the State of Gujarat and (ii) whether proviso (aa) to sub-clause (ii) of clause (1A) of Section
# ...

# %%
tokens = tok_ent['Token'].values

# %%
len(tokens)
# Out:
# 124

# %%
tokens = set(tokens)
tokens = list(tokens)

# %%
len(tokens)
# Out:
# 68

# %%
for t in tokens:
  print(t)
# Out:
# Madras District Municipality Act, 1920
# Calcutta Municipal Corporation Act, 1923
# Court
# V.R. Reddy and Andhyarujina
# Delhi Rent Control Act, 1958
# Madhya Pradesh Act
# Chief Judge of the Court
# BENCH
# Municipal Corporation Act
# appeals
# Bombay Rent Act
# Central Bank of India
# Commissioner
# Soli Sorabjee
# Rohinton Nariman
# Bombay Provincial Municipal Corporations Act
# Gujarat Municipalities Act, 1963
# Ratna Prabha
# Bombay Municipal Corporations Act
# Code of Civil Procedure
# Accommodation Control Act
# Bombay Rents, Hotel Rates and Lodging House Rates (Control) Act, 1944
# Municipal Corporations Act
# Civil Appeal
# B.P. JEEVAN REDDY
# Municipal Corporation Act, 1956
# appeal
# September, 1940
# S/Sri F.S. Nariman
# West Bengal Premises Rent control (Temporary Provisions) Act, 1950
# Sanghi
# Delhi Municipal Corporation Act, 1957
# Bombay Rents, Hotel and Lodging House Rates Control Act, 1944
# B.P. Jeevan Reddy
# High Courts
# M.P. Accommodation Control Act
# ...

# %%
for t in tokens:
  data_text.find(t)

# %%
tokens[0]
# Out:
# 'Madras District Municipality Act, 1920'

# %%
data_text.find(tokens[0])
# Out:
# 45895

# %%
data_text[45895:45895+len(tokens[0])]
# Out:
# 'Madras District Municipality Act, 1920'

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
#text = "Salesforce recently acquired Tableau." 
text = "appeals are preferred against the judgment of the Gujarat High Court"
doc = nlp(text)

# %%
for tok in doc: 
  print(tok.text, "-->",tok.dep_,"-->", tok.pos_)
  print(tok.dep_.find("ROOT"))
# Out:
# appeals --> nsubjpass --> NOUN
# -1
# are --> auxpass --> AUX
# -1
# preferred --> ROOT --> VERB
# 0
# against --> prep --> ADP
# -1
# the --> det --> DET
# -1
# judgment --> pobj --> NOUN
# -1
# of --> prep --> ADP
# -1
# the --> det --> DET
# -1
# Gujarat --> compound --> PROPN
# -1
# High --> compound --> PROPN
# -1
# Court --> pobj --> PROPN
# -1

# %%
def subtree_matcher(doc):
  subjpass = 0
  for i,tok in enumerate(doc):
    # find dependency tag that contains the text "subjpass"    
    if tok.dep_.find("subjpass") == True:
      subjpass = 1

  x = ''
  y = ''
  z = ''

  # if subjpass == 1 then sentence is passive
  if subjpass == 1:
    for i,tok in enumerate(doc):
      if tok.dep_.find("subjpass") == True:
        y = tok.text
      if tok.dep_.endswith("obj") == True:
        x = tok.text
      if tok.dep_.endswith("ROOT") == True:
        z = tok.text

  # if subjpass == 0 then sentence is not passive
  else:
    for i,tok in enumerate(doc):
      if tok.dep_.endswith("subj") == True:
        x = tok.text
      if tok.dep_.endswith("obj") == True:
        y = tok.text
      if tok.dep_.endswith("ROOT") == True:
        z = tok.text

  return x,z,y

# %%
subtree_matcher(doc)
# Out:
# ('Court', 'preferred', 'appeals')

# %%
sentences=nltk.sent_tokenize(data_text)

# %%
sentences

# %%
tokenized_sentences = [nltk.word_tokenize(sentence) for sentence in sentences]

# %%
tokenized_sentences

# %%
tagged_sentences = [nltk.pos_tag(sentence) for sentence in tokenized_sentences]

# %%
tagged_sentences
# Out:
# [[('PETITIONER', 'NN'),
#   (':', ':'),
#   ('COMMITTEE', 'NN'),
#   ('OF', 'NNP'),
#   ('MANAGEMENT', 'NNP'),
#   (',', ','),
#   ('K.D', 'NNP'),
#   ('.', '.')],
#  [('COLLEGE', 'NNP'),
#   ('Vs.', 'NNP'),
#   ('RESPONDENT', 'NNP'),
#   (':', ':'),
#   ('SHAMBHU', 'NNP'),
#   ('SARAN', 'NNP'),
#   ('PANDEY', 'NNP'),
#   ('DATE', 'NNP'),
#   ('OF', 'NNP'),
#   ('JUDGMENT28/10/1994', 'NNP'),
#   ('BENCH', 'NNP'),
#   (':', ':'),
#   ('RAMASWAMY', 'NNP'),
#   (',', ','),
#   ('K.', 'NNP'),
#   ('BENCH', 'NNP'),
#   (':', ':'),
#   ('RAMASWAMY', 'NNP'),
#   (',', ','),
#   ('K.', 'NNP'),
#   ('VENKATACHALA', 'NNP'),
#   ('N.', 'NNP'),
#   ('(', '('),
#   ('J', 'NNP'),
#   (')', ')'),
#   ('CITATION', 'NN'),
#   (':', ':'),
#   ('1995', 'CD'),
#   ('SCC', 'NNP'),
#   ('(', '('),
#   ('1', 'CD'),
#   (')', ')'),
#   ('404', 'CD'),
#   ('JT', 'JJ'),
#   ('1995', 'CD'),
#   ('(', '('),
#   ('1', 'CD'),
#   (')', ')'),
#   ('270', 'CD'),
#   ('1994', 'CD'),
#   ('SCALE', 'NNP'),
# ...

# %%
for sent in tagged_sentences:
  print(nltk.ne_chunk(sent))
# Out:
# (S
#   PETITIONER/NN
#   :/:
#   (ORGANIZATION COMMITTEE/NN OF/NNP)
#   MANAGEMENT/NNP
#   ,/,
#   K.D/NNP
#   ./.)
# (S
#   (ORGANIZATION COLLEGE/NNP)
#   Vs./NNP
#   RESPONDENT/NNP
#   :/:
#   (ORGANIZATION SHAMBHU/NNP)
#   SARAN/NNP
#   PANDEY/NNP
#   (ORGANIZATION DATE/NNP OF/NNP)
#   JUDGMENT28/10/1994/NNP
#   BENCH/NNP
#   :/:
#   RAMASWAMY/NNP
#   ,/,
#   K./NNP
#   BENCH/NNP
#   :/:
#   RAMASWAMY/NNP
#   ,/,
#   K./NNP
#   VENKATACHALA/NNP
#   N./NNP
#   (/(
#   J/NNP
#   )/)
#   CITATION/NN
#   :/:
#   1995/CD
#   SCC/NNP
#   (/(
#   1/CD
#   )/)
#   404/CD
#   JT/JJ
#   1995/CD
#   (/(
#   1/CD
#   )/)
#   270/CD
#   1994/CD
#   SCALE/NNP
#   (/(
#   4/CD
#   )/)
#   1082/CD
#   ACT/NN
#   :/:
#   HEADNOTE/NN
#   :/:
#   JUDGMENT/NN
#   :/:
#   ORDER/NN
#   1/CD
#   ./.)
# (S (GPE Leave/NNP) granted/VBN ./.)
# (S 2/CD ./.)
# (S
#   Admittedly/RB
#   ,/,
#   the/DT
#   respondent/NN
#   acted/VBD
#   as/IN
#   a/DT
#   principal/NN
#   of/IN
#   the/DT
#   appellant/NN
# ...

# %%
roles = r"""
 (.*(
 analyst|
 chair(wo)?man|
 commissioner|
 counsel|
 director|
 economist|
 editor|
 executive|
 foreman|
 governor|
 head|
 lawyer|
 leader|
 librarian).*)|
 manager|
 partner|
 president|
 producer|
 professor|
 researcher|
 writer|
 ,\sof\sthe?\s*  # "X, of (the) Y"
 """

# %%
import re
#IN = re.compile(r'.*\bin\b(?!\b.+ing)')
#IN = re.compile(r'.')
IN = re.compile(roles,re.VERBOSE)

# %%
for i, sent in enumerate(tagged_sentences):
  sent = nltk.ne_chunk(sent)
  rels = nltk.sem.extract_rels('PER','ORG',sent,corpus='conll2002',pattern=IN)
  for rel in rels:
    print(nltk.sem.rtuple(rel))
